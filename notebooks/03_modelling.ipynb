# %% [markdown]
# # 03 — Model Training & Evaluation
# Train, evaluate, and tune your XGBoost models.
# Once happy, move the final logic into `src/models.py`.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error
from xgboost import XGBClassifier, XGBRegressor

print('Libraries loaded ✓')

# %% [markdown]
# ## 1. Tournament winner model
# First, make sure `data/processed/team_features.csv` exists and has a `won_tournament` column.

# %%
from src.models import train_winner_model

model = train_winner_model()
if model:
    print('Model trained successfully')

# %% [markdown]
# ## 2. Hyperparameter tuning with GridSearchCV

# %%
# Uncomment and run this once you have labelled data

# team_features = pd.read_csv('../data/processed/team_features.csv')
# feature_cols = ['elo', 'win_rate_last20', 'goals_scored_avg', 'goals_conceded_avg']
# X = team_features[feature_cols].fillna(0)
# y = team_features['won_tournament']

# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'max_depth': [3, 4, 5],
#     'learning_rate': [0.01, 0.05, 0.1],
# }

# grid_search = GridSearchCV(XGBClassifier(random_state=42), param_grid, cv=5, scoring='accuracy')
# grid_search.fit(X, y)
# print('Best params:', grid_search.best_params_)
# print('Best CV accuracy:', grid_search.best_score_)

print('Uncomment the code above once you have labelled training data')

# %% [markdown]
# ## 3. SHAP explainability

# %%
# Uncomment once winner model is trained

# import shap
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)

# shap.summary_plot(shap_values, X_test, feature_names=feature_cols)
# plt.title('SHAP feature importance — tournament winner model')
# plt.tight_layout()
# plt.show()

print('SHAP explainability plots will appear here after model training')

# %% [markdown]
# ## 4. Backtest on historical WC data
# Validate your model by training on WC 1990–2018 data and testing on 2022.

# %%
# TODO: backtest structure
# train_data = team_features[team_features['year'] <= 2018]
# test_data  = team_features[team_features['year'] == 2022]

# model.fit(train_data[feature_cols], train_data['won_tournament'])
# preds = model.predict_proba(test_data[feature_cols])[:, 1]

# Check if Argentina (actual 2022 winner) was in the model's top 3
# top3 = test_data.nlargest(3, key=lambda x: preds)['team'].tolist()
# print(f'Model top 3 predictions for 2022: {top3}')
# print(f'Actual winner (Argentina) in top 3: {"Argentina" in top3}')

print('Backtest code — fill in once you have multi-year labelled data')

# %% [markdown]
# ## 5. Golden Boot model evaluation

# %%
from src.models import train_golden_boot_model

boot_model = train_golden_boot_model()
if boot_model:
    print('Golden Boot model trained')

# %% [markdown]
# ## 6. Save final models

# %%
from src.models import train_golden_glove_model, rank_playmakers

train_golden_glove_model()
rank_playmakers()

print('All models trained and saved to models/')
print('Run: streamlit run app.py  ← to launch your dashboard')
